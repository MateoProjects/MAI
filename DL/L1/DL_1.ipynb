# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# !cp /content/drive/MyDrive/DL/model.zip .
# !unzip model.zip
# Out:
# cp: cannot stat '/content/drive/MyDrive/DL/model.zip': No such file or directory
# unzip:  cannot find or open model.zip, model.zip.zip or model.zip.ZIP.

# %%
# !cp /content/drive/MyDrive/DL/main.py .
# !cp /content/drive/MyDrive/DL/model.py .
# !cp /content/drive/MyDrive/DL/data.py .

# %%
# !python3 main.py
# Out:
# 2022-04-21 20:14:41.692100: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# tcmalloc: large alloc 3991142400 bytes == 0x55cf013d2000 @  0x7f450a8bc1e7 0x7f450824d0ce 0x7f45082a9715 0x7f45082a9d1b 0x7f450834a333 0x55cdf37fc11c 0x55cdf37fbef0 0x55cdf3870123 0x55cdf37fd7aa 0x55cdf386b8f6 0x55cdf37fd7aa 0x55cdf386b8f6 0x55cdf386aa2e 0x55cdf386a723 0x55cdf3934812 0x55cdf3934b8d 0x55cdf3934a36 0x55cdf390c183 0x55cdf390be2c 0x7f45096a6c87 0x55cdf390bd0a
# 2022-04-21 20:15:13.993091: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 3991142400 exceeds 10% of free system memory.
# ...

# %%
# !cp summary_model.json /content/drive/MyDrive/DL/summary_model.json
# !cp model_epochs60_batchsize128.h5  /content/drive/MyDrive/DL/model_epochs_60_batchsize_128.h5

# %%
# !cp main.py /content/drive/MyDrive/MAI/DL/
# !cp model.py /content/drive/MyDrive/MAI/DL/
# !cp data.py /content/drive/MyDrive/MAI/DL/
# !cp data_ep* /content/drive/MyDrive/MAI/DL/
# !cp balanced_* /content/drive/MyDrive/MAI/DL/
# Out:
# cp: cannot create regular file '/content/drive/MyDrive/MAI/DL/': No such file or directory
# cp: cannot create regular file '/content/drive/MyDrive/MAI/DL/': No such file or directory
# cp: cannot create regular file '/content/drive/MyDrive/MAI/DL/': No such file or directory
# cp: cannot create regular file '/content/drive/MyDrive/MAI/DL/': No such file or directory
# cp: cannot create regular file '/content/drive/MyDrive/MAI/DL/': No such file or directory

# %% [markdown]
# ## Reset the environment for multiple executions

# %%
from numba import cuda
device = cuda.get_current_device()
device.reset()
